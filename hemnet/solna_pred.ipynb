# %% [markdown]
# # Hemnet Scrape Project Goals
# - forecast number of apartments sold in Sweden
# - limit analysis on Huvudsta to limit scraping needed
#     - Hemnet doesnt show more than 2500 listings
#     - limit search to 2017 inclusive
# - extrapolate from there and forecast a rough estimate of Hemnets revenue from apartment listings

# %%
import numpy as np
import pandas as pd
import locale
import matplotlib.pyplot as plt
import seaborn as sns
import scrape_functions as sf
import statsmodels.api as sm
import itertools
import operator
import importlib

# %%
importlib.reload(sf)
# Out:
# <module 'scrape_functions' from '/Users/ivenwinkelmann/Documents/GitHub/Portfolio/hemnet/scrape_functions.py'>

# %%
locale.setlocale(locale.LC_ALL, "sv_SE.UTF-8")
# Out:
# 'sv_SE.UTF-8'

# %%
url = "https://www.hemnet.se/salda/bostader?location_ids%5B%5D=473498&item_types%5B%5D=bostadsratt"

# %%
soup_list = sf.hemnet_pull_all(url)
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# /Users/ivenwinkelmann/Documents/GitHub/Portfolio/hemnet/scrape_functions.py:14: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 14 of the file /Users/ivenwinkelmann/Documents/GitHub/Portfolio/hemnet/scrape_functions.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = bs(driver.page_source)
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/ivenwinkelmann/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache

# %%
entry_key = "li.sold-results__normal-hit"
keys = {
      "street": "span.item-result-meta-attribute-is-bold.item-link.qa-selling-price-title"
    , "size_m2": "div.sold-property-listing__size > div > div.sold-property-listing__subheading.sold-property-listing--left"
    , "fee": "div.sold-property-listing__fee"
    , "price": "div.sold-property-listing__price > div:nth-child(1) > span"
    , "price_p_m2": "div.sold-property-listing__price-per-m2.sold-property-listing--left"
    , "date": "div.sold-property-listing__price > div:nth-child(2) > div.sold-property-listing__sold-date.sold-property-listing--left"
}

entry_list = sf.container_list_gen(entry_key, soup_list)

df = sf.container_scrape(entry_list, keys)

# %%
# fix fee column
# df["fee"] = df["fee"].str.replace(" ", "").str.replace(r"\xa0", "").str.replace("kr/mån", "").str.strip().astype("int")

# fix price column
df["price"] = df["price"].str.replace(" ", "").str.replace(r"\xa0", "").str.replace("Slutpris", "")\
    .str.replace("kr", "").str.strip()

# fix price_p_m2 column
df["price_p_m2"] = df["price_p_m2"].str.replace(" ", "").str.replace(r"\xa0", "")\
    .str.replace("kr/m²", "").str.strip()
    
# fix date column
df["date"] = df["date"].str.replace("Såld", "").str.strip()
df["date"] = pd.to_datetime(df["date"], format="%d %B %Y") 

# add month sold
df["month_sold"] = df["date"].dt.month

# add year sold
df["year_sold"] = df["date"].dt.year
# Out:
# /var/folders/dc/pptgd_mx41b6kk63x8dcgffw0000gn/T/ipykernel_63198/148652083.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["price"] = df["price"].str.replace(" ", "").str.replace(r"\xa0", "").str.replace("Slutpris", "")\
# /var/folders/dc/pptgd_mx41b6kk63x8dcgffw0000gn/T/ipykernel_63198/148652083.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["price_p_m2"] = df["price_p_m2"].str.replace(" ", "").str.replace(r"\xa0", "")\

# %%
sf.save_object(df, "hemnet_df.pkl")

# %%
plt.rcParams["figure.figsize"] = (16, 10)

# %%
df = df.set_index("date")
df["apts_sold"] = df.groupby("date")["street"].count()
se = df["apts_sold"].resample("MS").sum()

# %%
se.plot(figsize=(12,6))
plt.ylabel("Apartments sold / month")
plt.show()

# %% [markdown]
# # Forecasting of Apartments sold

# %%
from prophet import Prophet
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics

# %%
pdf = se.to_frame().reset_index().rename(columns={'date': 'ds', 'apts_sold': 'y'})

# %%
model = Prophet(changepoint_prior_scale=0.5)
model.fit(pdf)

future = model.make_future_dataframe(periods=72, freq="MS")
forecast = model.predict(future)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -130.115
# Iteration  1. Log joint probability =    28.7736. Improved by 158.889.
# Iteration  2. Log joint probability =    86.0148. Improved by 57.2411.
# Iteration  3. Log joint probability =    86.0183. Improved by 0.00351128.
# Iteration  4. Log joint probability =    90.5687. Improved by 4.5504.
# Iteration  5. Log joint probability =    90.5962. Improved by 0.0275534.
# Iteration  6. Log joint probability =    90.6051. Improved by 0.00892333.
# Iteration  7. Log joint probability =    90.6089. Improved by 0.00373683.
# Iteration  8. Log joint probability =     90.642. Improved by 0.0331181.
# Iteration  9. Log joint probability =     90.642. Improved by 3.41649e-05.
# Iteration 10. Log joint probability =    90.7239. Improved by 0.0818786.
# Iteration 11. Log joint probability =    90.8902. Improved by 0.166322.
# Iteration 12. Log joint probability =    96.5782. Improved by 5.68795.
# Iteration 13. Log joint probability =    97.7306. Improved by 1.15241.
# Iteration 14. Log joint probability =    100.989. Improved by 3.25885.
# Iteration 15. Log joint probability =    101.591. Improved by 0.601711.
# Iteration 16. Log joint probability =    101.853. Improved by 0.262192.
# Iteration 17. Log joint probability =    102.141. Improved by 0.287613.
# Iteration 18. Log joint probability =    102.338. Improved by 0.196935.
# Iteration 19. Log joint probability =    102.345. Improved by 0.00703429.
# Iteration 20. Log joint probability =    102.435. Improved by 0.0904276.
# Iteration 21. Log joint probability =    102.448. Improved by 0.0130958.
# Iteration 22. Log joint probability =    102.527. Improved by 0.0781152.
# Iteration 23. Log joint probability =    102.596. Improved by 0.0693484.
# Iteration 24. Log joint probability =    102.821. Improved by 0.225376.
# Iteration 25. Log joint probability =    102.918. Improved by 0.0967014.
# Iteration 26. Log joint probability =    102.944. Improved by 0.0256782.
# Iteration 27. Log joint probability =    103.053. Improved by 0.109469.
# Iteration 28. Log joint probability =    103.092. Improved by 0.0387763.
# Iteration 29. Log joint probability =    103.112. Improved by 0.0199092.
# Iteration 30. Log joint probability =     103.12. Improved by 0.00803027.
# Iteration 31. Log joint probability =     103.17. Improved by 0.0502296.
# Iteration 32. Log joint probability =    103.176. Improved by 0.00633802.
# Iteration 33. Log joint probability =    103.206. Improved by 0.0292565.
# Iteration 34. Log joint probability =    103.216. Improved by 0.0105549.
# Iteration 35. Log joint probability =    103.241. Improved by 0.0247657.
# Iteration 36. Log joint probability =    103.256. Improved by 0.0146517.
# Iteration 37. Log joint probability =    103.276. Improved by 0.0203978.
# Iteration 38. Log joint probability =    103.295. Improved by 0.0186214.
# Iteration 39. Log joint probability =    103.311. Improved by 0.0161433.
# Iteration 40. Log joint probability =    103.333. Improved by 0.0224641.
# Iteration 41. Log joint probability =    103.345. Improved by 0.0119869.
# Iteration 42. Log joint probability =    103.371. Improved by 0.0262211.
# Iteration 43. Log joint probability =    103.379. Improved by 0.00796651.
# Iteration 44. Log joint probability =    103.409. Improved by 0.0298697.
# Iteration 45. Log joint probability =    103.413. Improved by 0.00406106.
# Iteration 96. Log joint probability =    105.875. Improved by 8.01647e-05.
# Iteration 97. Log joint probability =    105.875. Improved by 3.3073e-06.
# Iteration 98. Log joint probability =    105.875. Improved by 0.000193496.
# Iteration 99. Log joint probability =    105.875. Improved by 3.81374e-05.
# Iteration 100. Log joint probability =    105.875. Improved by 2.98203e-05.
# Iteration 101. Log joint probability =    105.875. Improved by 6.25751e-05.
# Iteration 102. Log joint probability =    105.875. Improved by 4.50921e-05.
# Iteration 103. Log joint probability =    105.875. Improved by 2.61518e-06.
# Iteration 104. Log joint probability =    105.875. Improved by 3.60611e-05.
# Iteration 105. Log joint probability =    105.875. Improved by 7.59758e-06.
# Iteration 106. Log joint probability =    105.875. Improved by 8.31572e-06.
# Iteration 107. Log joint probability =    105.875. Improved by 2.41937e-05.
# Iteration 108. Log joint probability =    105.875. Improved by 1.40898e-05.
# Iteration 109. Log joint probability =    105.875. Improved by 1.82114e-05.
# Iteration 110. Log joint probability =    105.875. Improved by 1.99287e-05.
# Iteration 111. Log joint probability =    105.875. Improved by 1.24489e-05.
# Iteration 112. Log joint probability =    105.875. Improved by 1.70852e-07.
# Iteration 113. Log joint probability =    105.875. Improved by 6.87482e-06.
# Iteration 114. Log joint probability =    105.875. Improved by 1.70623e-06.
# Iteration 115. Log joint probability =    105.875. Improved by 3.29683e-06.
# Iteration 116. Log joint probability =    105.875. Improved by 2.5286e-06.
# Iteration 117. Log joint probability =    105.875. Improved by 2.52099e-06.
# Iteration 118. Log joint probability =    105.875. Improved by 1.03628e-06.
# Iteration 119. Log joint probability =    105.875. Improved by 1.21203e-06.
# Iteration 120. Log joint probability =    105.875. Improved by 6.06431e-07.
# Iteration 121. Log joint probability =    105.875. Improved by 1.25819e-06.
# Iteration 122. Log joint probability =    105.875. Improved by 5.19494e-08.
# Iteration 123. Log joint probability =    105.875. Improved by 1.66594e-07.
# Iteration 124. Log joint probability =    105.875. Improved by 4.13747e-07.
# Iteration 125. Log joint probability =    105.875. Improved by 4.24677e-07.
# Iteration 126. Log joint probability =    105.875. Improved by 5.23889e-07.
# Iteration 127. Log joint probability =    105.875. Improved by 3.98406e-07.
# Iteration 128. Log joint probability =    105.875. Improved by 2.68354e-07.
# Iteration 129. Log joint probability =    105.875. Improved by 4.72833e-07.
# Iteration 130. Log joint probability =    105.875. Improved by 2.11934e-07.
# Iteration 131. Log joint probability =    105.875. Improved by 1.81216e-07.
# Iteration 132. Log joint probability =    105.875. Improved by 1.32621e-07.
# Iteration 133. Log joint probability =    105.875. Improved by 8.79686e-09.

# %%
model.plot(forecast)
plt.title("Apartments sold Forecast")
plt.ylabel("Apartments sold per month")
plt.xlabel("Year")
plt.show()

# %%
model.plot_components(forecast)
plt.show()

# %%
# cross validation
param_grid = {  
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5]
    # 'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0]
    # 'changepoint_prior_scale': [0.001],
    # 'seasonality_prior_scale': [0.01]
}

cutoffs = pd.to_datetime(['2017-10-01', '2018-10-01', '2019-10-01'])
# cutoffs = pd.to_datetime(['2017-01-01'])

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # Store the RMSEs for each params here

# Use cross validation to evaluate all parameters
for params in all_params:
    m = Prophet(**params).fit(pdf)  # Fit model with given params
    df_cv = cross_validation(m, cutoffs=cutoffs, horizon='365 days', parallel="processes")
    df_p = performance_metrics(df_cv)
    rmses.append(df_p['rmse'].values[0])

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses
